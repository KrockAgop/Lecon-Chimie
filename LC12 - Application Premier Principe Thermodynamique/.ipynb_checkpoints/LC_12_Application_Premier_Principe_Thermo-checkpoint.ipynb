# %%
import numpy as np
import os
from matplotlib import pyplot as plt
from scipy.optimize import curve_fit
plt.rcParams["figure.figsize"]=10,5

# %%
def my_round(X , DX) :
    Ndecimal = np.int(np.ceil(np.abs(np.log10(DX))))
    DX = np.around( DX , Ndecimal )
    X = np.around( X , Ndecimal )
    return X , DX

def affine(x,a,b) :
    return a * x + b

def lineaire(x,a) :
    return a * x

# %%
#T=np.array([21.399999999999999,21.800000000000001,22.300000000000001,22.899999999999999,23.300000000000001,23.699999999999999,24.100000000000001,24.5,24.899999999999999,25.399999999999999,25.899999999999999,26.399999999999999,26.899999999999999,27.399999999999999,27.800000000000001,28.399999999999999,28.899999999999999,29.399999999999999,29.699999999999999,30.300000000000001,30.5,30.800000000000001,31.100000000000001,31.5,31.800000000000001,32.299999999999997,32.700000000000003,33,33.399999999999999,33.799999999999997,34.100000000000001,34.399999999999999,34.700000000000003,34.899999999999999,35.200000000000003,35.5,35.700000000000003,35.899999999999999,36.200000000000003,36.299999999999997])
#V = np.array([0,0.5,1,1.6000000000000001,2.2000000000000002,2.6000000000000001,3.2000000000000002,3.7000000000000002,4.2000000000000002,4.7000000000000002,5.5,6.0999999999999996,6.7000000000000002,7.4000000000000004,8.0999999999999996,8.9000000000000004,9.5999999999999996,10.199999999999999,10.800000000000001,11.5,12.1,12.6,13.199999999999999,14,14.6,15.4,16.199999999999999,16.800000000000001,17.5,18.300000000000001,18.899999999999999,19.5,20.199999999999999,20.600000000000001,21.399999999999999,22,22.5,23,23.5,24])

os.system('ls -lrt')
# Out:
# 0

# %%
# Plot resultat : 


# %matplotlib notebook
plt.figure()

plt.xlabel('$V$')
plt.ylabel('$T$')

plt.errorbar( V , T , color='tomato', fmt = 'o',markersize=4, label='data')

plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="951">

# %%
xmin1 = np.float(input('Debut premiere acidite : '))
xmax1 = np.float(input('Fin premiere acidite : '))

xmin2 = np.float(input('Debut deuxieme acidite : '))
xmax2 = np.float(input('Fin deuxieme acidite : '))
# Out:
# Debut premiere acidite : 0
# Fin premiere acidite : 9
# Debut deuxieme acidite : 13
# Fin deuxieme acidite : 23

# %%
# Plot resultat : 

V1 = V[(V>xmin1)&(V<xmax1)]
T1 = T[(V>xmin1)&(V<xmax1)]

V2 = V[(V>xmin2)&(V<xmax2)]
T2 = T[(V>xmin2)&(V<xmax2)]

Vg = V[(V<xmin2)&(V>xmax1)]
Tg = T[(V<xmin2)&(V>xmax1)]
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# Regression Affine : 
Regr1, pcov1 = curve_fit(affine , V1 , T1)#, sigma = Y_err) 
Regr_err1 = np.sqrt(np.diag(pcov1))

Regr2, pcov2 = curve_fit(affine , V2 , T2)#, sigma = Y_err) 
Regr_err2 = np.sqrt(np.diag(pcov2))

# %%
X1 = np.arange(xmin1,xmin2)
X2 = np.arange(xmax1,xmax2)


# %matplotlib notebook
fig,ax1 = plt.subplots()

ax1.set_xlabel('$V$')
ax1.set_ylabel('$T$')

ax1.axvspan(xmin1, xmax1, alpha=0.1, color='tomato')
ax1.axvspan(xmin2, xmax2, alpha=0.1, color='royalblue')


ax1.errorbar( V1 , T1 , color='tomato', fmt = 'o',markersize=4, label='acidite 1')
ax1.errorbar( V2 , T2 , color='royalblue', fmt = 'o',markersize=4, label='acidite 2')
ax1.errorbar( Vg , Tg , color='grey', fmt = 'o',markersize=4)

ax1.plot(X1,Regr1[0]*X1+Regr1[1],color='tomato')
ax1.plot(X2,Regr2[0]*X2+Regr2[1],color='royalblue')

A1,Aerr1 = my_round(Regr1[0],Regr_err1[0])
B1,Berr1 = my_round(Regr1[1],Regr_err1[1])

A2,Aerr2 = my_round(Regr2[0],Regr_err2[0])
B2,Berr2 = my_round(Regr2[1],Regr_err2[1])

print(Regr1)
print(Regr2)


print ('Premiere acidite : ('+str(A1)+' +/- '+str(Aerr1)+')*V + ('+str(B1)+' +/- '+str(Berr1)+')')
print ('Deuxieme acidite : ('+str(A2)+' +/- '+str(Aerr2)+')*V + ('+str(B2)+' +/- '+str(Berr2)+')')


ax1.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
# [ 0.78058982 21.59125573]
# [ 0.49958323 24.57753239]
# Premiere acidite : (0.781 +/- 0.009)*V + (21.59 +/- 0.05)
# Deuxieme acidite : (0.5 +/- 0.007)*V + (24.6 +/- 0.1)
